# %% [markdown]
# # us-accidents-analysis
#
# Use the "Run" button to execute the code.

# %%
# Jovian Commit Essentianls
# Please retain and execute this cell wothout modifying the contents for `jovian.com`
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('us-accidents-analysis')
jovian.set_colab_id('1vrLH8BhzAmhSCeNFLMcZi3rR_zkTnXng')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 818.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # US Accidents Exploratory Data Analysis

# %% [markdown]
# ## Download the data
#
# TODO - talk about EDA
#
# TODO - talk about tha dataset (source, what it contains, how it will be usefull)
#   - Kaggle
#   - information about accidents
#   - can be useful to prevent accidents
#   - mention that this does not contain data about New York

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
download_url = 'https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vkumar764
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
# ...
# 100%|██████████| 653M/653M [00:03<00:00, 195MB/s]

# %% [markdown]
# ## Data Preparation and Cleaning
#
# - Load the file using Pandas
# - Look at some information about the data & the columns
# - Fix any missing or incorrect values

# %%
import pandas as pd

# %%
file_path = './us-accidents/US_Accidents_March23.csv'

# Load the data in chunks
chunk_size = 10000  # Number of rows per chunk
chunks = []

for chunk in pd.read_csv(file_path, chunksize=chunk_size):
    chunks.append(chunk)

# Concatenate all chunks into a single DataFrame
df = pd.concat(chunks, ignore_index=True)

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
len(df.columns)
# Out:
# 46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 13

# %% [markdown]
# Percentage of Missing Values per column

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False)/ len(df)
missing_percentages
# Out:
# End_Lng                  4.402935e-01
# End_Lat                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Sunrise_Sunset           3.007869e-03
# Civil_Twilight           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Nautical_Twilight        3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# ID                       0.000000e+00
# Distance(mi)             0.000000e+00
# Start_Lng                0.000000e+00
# ...

# %%
missing_percentages[missing_percentages != 0]
# Out:
# End_Lng                  4.402935e-01
# End_Lat                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Sunrise_Sunset           3.007869e-03
# Civil_Twilight           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Nautical_Twilight        3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Columns we'll analyse
# 1. City
# 2. Start Time
# 3. Start Lat, Start Lng
# 4. Temperature
# 5. Weather Condition

# %% [markdown]
# ### City

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
#                   ...
# Rapid River           1
# Cat Spring            1
# Glenwood City         1
# Downing               1
# Marfa                 1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.distplot(cities_by_accident)
# Out:
# <ipython-input-21-1f460903cad6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cities_by_accident)
# <Axes: xlabel='count', ylabel='Density'>

# %%
high_accident_cities = cities_by_accident[cities_by_accident >= 1000]
low_accident_cities = cities_by_accident[cities_by_accident <1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
sns.distplot(high_accident_cities)
# Out:
# <ipython-input-24-50976d58a416>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities)
# <Axes: xlabel='count', ylabel='Density'>

# %%
sns.distplot(low_accident_cities)
# Out:
# <ipython-input-25-a69b07a78e7c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(low_accident_cities)
# <Axes: xlabel='count', ylabel='Density'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# City
# American Fork-Pleasant Grove    1
# Waldoboro                       1
# Kinsley                         1
# Killona                         1
# Jeanerette                      1
#                                ..
# Rapid River                     1
# Cat Spring                      1
# Glenwood City                   1
# Downing                         1
# Marfa                           1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ### Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
# For ISO8601 format
pd.to_datetime(df.Start_Time, format='ISO8601')

# For mixed formats
df.Start_Time = pd.to_datetime(df.Start_Time, format='mixed')

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False,norm_hist = True)
# Out:
# <ipython-input-29-6bd662365bb7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False,norm_hist = True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# A high percentage of accedents happen between 6 to 8 am and 3 to 6 pm (probably trafic is higher at these times)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7,kde=False,norm_hist=True)
# Out:
# <ipython-input-30-40a94cc134b6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins=7,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays?

# %%
mondays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(df.Start_Time.dt.hour, bins=24,kde=False,norm_hist=True)
# Out:
# <ipython-input-31-b4420607b10d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# On Sundays, the peak occurs between 10 am to 3 pm unlike week days

# %%
df_2020 = df[df.Start_Time.dt.year == 2016]
df_2020_Bing = df_2020[df_2020.Source == 'MapQuest']
sns.distplot(df_2020.Start_Time.dt.month, bins=12,kde=False,norm_hist=True)
# Out:
# <ipython-input-37-c14f188f9f9e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2020.Start_Time.dt.month, bins=12,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# - Much data is missing for 2016 and 2017.
# - There seems to be some issue with the Bing Data.

# %%
df.Source.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Start Lattitude & Longitude

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1*len(df)) )
sns.scatterplot(x=sample_df.Start_Lng, y=df.Start_Lat, size = 0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
# !pip install folium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import folium

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat,lon
# Out:
# (39.865147, -84.058723)

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.01 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Ask and Answer Questions
#
# 1. Are there more accidents in warmer or colder areas?
# 2. Which 5 states have the highest number of accidents? How about per capita?
# 3. Does New York show up in the data?
# If yes, why is the count lower if this is the most populated city?
# 4. Among the top 100 cities in number of accidents, which states do they belong to most frequently?
# 5. What time of the day are accidents most frequent in? - ANSWERED
# 6. Which days of the week have the most accidents?
# 7. Which months have the most accidents?
# 8. What is the trend of accidents year over year (decreasing/increasing)?
# 9. When is accedents per unit of traffic the highest?

# %% [markdown]
# ## Summary and Conclusions
#
# Insights:
# - No data from New York
# - The number of accidents per cities decreases exponentialy
# - Less than 8% of cities have more than 1000 yearly accidents.
# - Over 1000 cities have reported just one accident (need to investigate)

# %%
import jovian
